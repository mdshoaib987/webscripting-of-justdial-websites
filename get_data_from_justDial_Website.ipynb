# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
# create a new Firefox session
driver = webdriver.Firefox()
driver.implicitly_wait(30)
driver.maximize_window()

# Navigate to the application home page
driver.get("https://www.justdial.com/Delhi/Automotive-Lubricant-Dealers/nct-10574354")

driver.implicitly_wait(20)

b2b = driver.find_element_by_link_text('Parnami Enterprises')
driver.implicitly_wait(20)

b2b.click()

automobie = driver.find_element_by_link_text('Edit This')
driver.implicitly_wait(20)
automobie.click()

edit = driver.find_element_by_link_text('Edit / Modify this business')
driver.implicitly_wait(20)
edit.click()

driver.implicitly_wait(30)
driver.find_element_by_id("rdoUser").click()
#
driver.implicitly_wait(20)
driver.find_elements_by_xpath('//*[@id="cat"]/button')[0].click()

inputs = driver.find_elements_by_xpath('//form[@name="os_home"]//input')
for data in inputs:
   print(data.get_attribute('value'))

formValue = driver.find_element_by_xpath('//*[@id="colcontent"]/div[1]/p[10]/span/span[2]')
print(formValue.text)
# Out:
# 1
# 0
# 0
#
#
#
#
#
# 0
# 0
# 0
# 0
# Parnami Enterprises
# Shop Number  38
# Old Delhi Road
# Near Sector 12 A , Near Telephone Exchange
#  Sector 12a
# Gurgaon
#
# Haryana
# India
#
#
#
# Save
# 1
# OK
# 28.468666083333
# 77.035902083333
#
# Parnami Enterprises
#
#
#
#
#
#
#
#
#
# 1
# 1
#  Sector 12a
#  Sector 12a
# Gurgaon
# gurgaon
# Delhi
# 0
#
# 124
# 1041890919#@#Automotive Lubricant Dealers|@~@|1975#@#Ball Bearing Dealers|@~@|944#@#Chemical Dealers|@~@|100702#@#Diesel Engine Dealers|@~@|5985#@#Grease Dealers|@~@|464975#@#Industrial Lubricant Dealers|@~@|3852#@#Lubricant Dealers|@~@|291473#@#Lubricant Dealers-Total|@~@|105703#@#Lubricant Oil Dealers|@~@|487427#@#Lubricant Oil Dealers-Castrol|@~@|441953#@#Lubricant Oil Distributors|@~@|1000460717#@#Lubricant Oil Distributors-Servo|@~@|
# 1041890919#@#Automotive Lubricant Dealers|@~@|1975#@#Ball Bearing Dealers|@~@|944#@#Chemical Dealers|@~@|100702#@#Diesel Engine Dealers|@~@|5985#@#Grease Dealers|@~@|464975#@#Industrial Lubricant Dealers|@~@|3852#@#Lubricant Dealers|@~@|291473#@#Lubricant Dealers-Total|@~@|105703#@#Lubricant Oil Dealers|@~@|487427#@#Lubricant Oil Dealers-Castrol|@~@|441953#@#Lubricant Oil Distributors|@~@|1000460717#@#Lubricant Oil Distributors-Servo|@~@|
#
#
#
# 011P1222144513H9T5H1
# P1222144513H9T5H1
#
#
#
#
#
#
# 0
# 1
#
#
#
# skf_parnami@yahoo.com,
#
#
#
#
# 944,1975,3852,5985,100702,105703,291473,441953,464975,487427,1041890919,1000460717
# 6
#
#
#
# 1041890919,1975,944,100702,5985,464975,3852,291473,105703,487427,441953,1000460717,
#
# 0
# Shop Number 38, Old Delhi Road, Near Sector 12 A , Near Telephone Exchange, Sector 12a, Gurgaon 122001, Haryana , India,
